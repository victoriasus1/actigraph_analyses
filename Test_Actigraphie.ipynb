# %% [markdown]
# # Pipeline for actigraph analyses:

# %% [markdown]
# ### Some setup and import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the raw data!

# %%
data = pd.read_csv ('Data/test.csv', skiprows= 162).drop(['Ligne','Marqueur','Lumière blanche','Lumière rouge','Lumière verte','Lumière bleue','Unnamed: 14'],axis=1)
data
# Out:
#       Jour        Date     Heure  Statut hors poignet Activité Sommeil/Éveil  \
# 0        1  2021-08-11  15:14:00                    0      NAN           NAN
# 1        1  2021-08-11  15:15:00                    0      NAN           NAN
# 2        1  2021-08-11  15:16:00                    0      NAN           NAN
# 3        1  2021-08-11  15:17:00                    0      NAN           NAN
# 4        1  2021-08-11  15:18:00                    0      NAN           NAN
# ...    ...         ...       ...                  ...      ...           ...
# 8277     7  2021-08-17  09:11:00                    0      139             1
# 8278     7  2021-08-17  09:12:00                    0      144             1
# 8279     7  2021-08-17  09:13:00                    0      182             1
# 8280     7  2021-08-17  09:14:00                    0       17           NAN
# 8281     7  2021-08-17  09:15:00                    0        0           NAN
#
#      Statut de l’intervalle Statut Sommeil/Éveil
# 0                  ACTIVITÉ                  NAN
# 1                  ACTIVITÉ                  NAN
# 2                  ACTIVITÉ                  NAN
# 3                  ACTIVITÉ                  NAN
# 4                  ACTIVITÉ                  NAN
# ...                     ...                  ...
# 8277               ACTIVITÉ                  NAN
# 8278               ACTIVITÉ                  NAN
# 8279               ACTIVITÉ                  NAN
# 8280               ACTIVITÉ                  NAN
# 8281               ACTIVITÉ                  NAN
#
# [8282 rows x 8 columns]

# %%
print(data.iloc[0:406])
# Out:
#      Jour        Date     Heure  Statut hors poignet Activité Sommeil/Éveil  \
# 0       1  2021-08-11  15:14:00                    0      NAN           NAN
# 1       1  2021-08-11  15:15:00                    0      NAN           NAN
# 2       1  2021-08-11  15:16:00                    0      NAN           NAN
# 3       1  2021-08-11  15:17:00                    0      NAN           NAN
# 4       1  2021-08-11  15:18:00                    0      NAN           NAN
# ..    ...         ...       ...                  ...      ...           ...
# 401     1  2021-08-11  21:55:00                    1      NAN           NAN
# 402     1  2021-08-11  21:56:00                    1      NAN           NAN
# 403     1  2021-08-11  21:57:00                    1      NAN           NAN
# 404     1  2021-08-11  21:58:00                    1      NAN           NAN
# 405     1  2021-08-11  21:59:00                    1      NAN           NAN
#
#     Statut de l’intervalle Statut Sommeil/Éveil
# 0                 ACTIVITÉ                  NAN
# 1                 ACTIVITÉ                  NAN
# 2                 ACTIVITÉ                  NAN
# 3                 ACTIVITÉ                  NAN
# 4                 ACTIVITÉ                  NAN
# ..                     ...                  ...
# 401                  EXCLU                EXCLU
# 402                  EXCLU                EXCLU
# 403                  EXCLU                EXCLU
# 404                  EXCLU                EXCLU
# 405                  EXCLU                EXCLU
#
# [406 rows x 8 columns]

# %% [markdown]
# ### Remove data of day 1

# %%
df=data.drop(data.index[0:406],axis=0).reset_index(drop=True)
df
# Out:
#       Jour        Date     Heure  Statut hors poignet Activité Sommeil/Éveil  \
# 0        1  2021-08-11  22:00:00                    1      NAN           NAN
# 1        1  2021-08-11  22:01:00                    0      176           NAN
# 2        1  2021-08-11  22:02:00                    0      482             1
# 3        1  2021-08-11  22:03:00                    0      373             1
# 4        1  2021-08-11  22:04:00                    0      452             1
# ...    ...         ...       ...                  ...      ...           ...
# 7871     7  2021-08-17  09:11:00                    0      139             1
# 7872     7  2021-08-17  09:12:00                    0      144             1
# 7873     7  2021-08-17  09:13:00                    0      182             1
# 7874     7  2021-08-17  09:14:00                    0       17           NAN
# 7875     7  2021-08-17  09:15:00                    0        0           NAN
#
#      Statut de l’intervalle Statut Sommeil/Éveil
# 0                     EXCLU                EXCLU
# 1                  ACTIVITÉ                  NAN
# 2                  ACTIVITÉ                  NAN
# 3                  ACTIVITÉ                  NAN
# 4                  ACTIVITÉ                  NAN
# ...                     ...                  ...
# 7871               ACTIVITÉ                  NAN
# 7872               ACTIVITÉ                  NAN
# 7873               ACTIVITÉ                  NAN
# 7874               ACTIVITÉ                  NAN
# 7875               ACTIVITÉ                  NAN
#
# [7876 rows x 8 columns]

# %% [markdown]
# ### Define day/ night intervals

# %%
day_night_intervals= df[(df["Heure"]== '22:00:00')|(df["Heure"]== '07:00:00')] 
day_night_intervals
# Out:
#       Jour        Date     Heure  Statut hors poignet Activité Sommeil/Éveil  \
# 0        1  2021-08-11  22:00:00                    1      NAN           NAN
# 540      2  2021-08-12  07:00:00                    0       23             0
# 1440     2  2021-08-12  22:00:00                    0      261             1
# 1980     3  2021-08-13  07:00:00                    0        0             0
# 2880     3  2021-08-13  22:00:00                    0      339             1
# 3420     4  2021-08-14  07:00:00                    0       82             1
# 4320     4  2021-08-14  22:00:00                    0       10             0
# 4860     5  2021-08-15  07:00:00                    0        0             0
# 5760     5  2021-08-15  22:00:00                    0       60             1
# 6300     6  2021-08-16  07:00:00                    0        0             0
# 7200     6  2021-08-16  22:00:00                    0      125             1
# 7740     7  2021-08-17  07:00:00                    0        0             0
#
#      Statut de l’intervalle Statut Sommeil/Éveil
# 0                     EXCLU                EXCLU
# 540                 S-REPOS                  NAN
# 1440               ACTIVITÉ                  NAN
# 1980                S-REPOS                  NAN
# 2880               ACTIVITÉ                  NAN
# 3420                S-REPOS                  NAN
# 4320               ACTIVITÉ                  NAN
# 4860                S-REPOS                  NAN
# 5760               ACTIVITÉ                  NAN
# 6300                S-REPOS                  NAN
# 7200               ACTIVITÉ                  NAN
# 7740                S-REPOS                  NAN

# %% [markdown]
# ### Add a column "index1"

# %%
df = df.rename_axis('index1').reset_index()
df
# Out:
#       index1  Jour        Date     Heure  Statut hors poignet Activité  \
# 0          0     1  2021-08-11  22:00:00                    1      NAN
# 1          1     1  2021-08-11  22:01:00                    0      176
# 2          2     1  2021-08-11  22:02:00                    0      482
# 3          3     1  2021-08-11  22:03:00                    0      373
# 4          4     1  2021-08-11  22:04:00                    0      452
# ...      ...   ...         ...       ...                  ...      ...
# 7871    7871     7  2021-08-17  09:11:00                    0      139
# 7872    7872     7  2021-08-17  09:12:00                    0      144
# 7873    7873     7  2021-08-17  09:13:00                    0      182
# 7874    7874     7  2021-08-17  09:14:00                    0       17
# 7875    7875     7  2021-08-17  09:15:00                    0        0
#
#      Sommeil/Éveil Statut de l’intervalle Statut Sommeil/Éveil
# 0              NAN                  EXCLU                EXCLU
# 1              NAN               ACTIVITÉ                  NAN
# 2                1               ACTIVITÉ                  NAN
# 3                1               ACTIVITÉ                  NAN
# 4                1               ACTIVITÉ                  NAN
# ...            ...                    ...                  ...
# 7871             1               ACTIVITÉ                  NAN
# 7872             1               ACTIVITÉ                  NAN
# 7873             1               ACTIVITÉ                  NAN
# 7874           NAN               ACTIVITÉ                  NAN
# 7875           NAN               ACTIVITÉ                  NAN
#
# [7876 rows x 9 columns]

# %% [markdown]
# ### Create function that checks multiple conditions

# %%
def rename_periods(x):
    if x in range(0, 540):
        return ('night_1')
    if x in range(540, 1440):
        return ('day_2')
    if x in range(1440, 1980):
        return ('night_2')
    if x in range(1980, 2880):
        return ('day_3')
    if x in range(2880, 3420):
        return ('night_3')
    if x in range(3420, 4320):
        return ('day_4')
    if x in range(4320, 4860):
        return ('night_4')
    if x in range(4860, 5760):
        return ('day_5')
    if x in range(5760, 6300):
        return ('night_5')
    if x in range(6300, 7200):
        return ('day_6')
    if x in range(7200, 7740):
        return ('night_6')
    if x in range(7740, 7876):
        return ('day_7')

# %% [markdown]
# ### Apply function on extra column added earlier

# %%
df['index1'] = df['index1'].apply(rename_periods)
df
# Out:
#        index1  Jour        Date     Heure  Statut hors poignet Activité  \
# 0     night_1     1  2021-08-11  22:00:00                    1      NAN
# 1     night_1     1  2021-08-11  22:01:00                    0      176
# 2     night_1     1  2021-08-11  22:02:00                    0      482
# 3     night_1     1  2021-08-11  22:03:00                    0      373
# 4     night_1     1  2021-08-11  22:04:00                    0      452
# ...       ...   ...         ...       ...                  ...      ...
# 7871    day_7     7  2021-08-17  09:11:00                    0      139
# 7872    day_7     7  2021-08-17  09:12:00                    0      144
# 7873    day_7     7  2021-08-17  09:13:00                    0      182
# 7874    day_7     7  2021-08-17  09:14:00                    0       17
# 7875    day_7     7  2021-08-17  09:15:00                    0        0
#
#      Sommeil/Éveil Statut de l’intervalle Statut Sommeil/Éveil
# 0              NAN                  EXCLU                EXCLU
# 1              NAN               ACTIVITÉ                  NAN
# 2                1               ACTIVITÉ                  NAN
# 3                1               ACTIVITÉ                  NAN
# 4                1               ACTIVITÉ                  NAN
# ...            ...                    ...                  ...
# 7871             1               ACTIVITÉ                  NAN
# 7872             1               ACTIVITÉ                  NAN
# 7873             1               ACTIVITÉ                  NAN
# 7874           NAN               ACTIVITÉ                  NAN
# 7875           NAN               ACTIVITÉ                  NAN
#
# [7876 rows x 9 columns]

# %% [markdown]
# ### Rename the column

# %%
df_clean =df.rename(columns={"index1":"periods"})

# %%
df_clean
# Out:
#       periods  Jour        Date     Heure  Statut hors poignet Activité  \
# 0     night_1     1  2021-08-11  22:00:00                    1      NAN
# 1     night_1     1  2021-08-11  22:01:00                    0      176
# 2     night_1     1  2021-08-11  22:02:00                    0      482
# 3     night_1     1  2021-08-11  22:03:00                    0      373
# 4     night_1     1  2021-08-11  22:04:00                    0      452
# ...       ...   ...         ...       ...                  ...      ...
# 7871    day_7     7  2021-08-17  09:11:00                    0      139
# 7872    day_7     7  2021-08-17  09:12:00                    0      144
# 7873    day_7     7  2021-08-17  09:13:00                    0      182
# 7874    day_7     7  2021-08-17  09:14:00                    0       17
# 7875    day_7     7  2021-08-17  09:15:00                    0        0
#
#      Sommeil/Éveil Statut de l’intervalle Statut Sommeil/Éveil
# 0              NAN                  EXCLU                EXCLU
# 1              NAN               ACTIVITÉ                  NAN
# 2                1               ACTIVITÉ                  NAN
# 3                1               ACTIVITÉ                  NAN
# 4                1               ACTIVITÉ                  NAN
# ...            ...                    ...                  ...
# 7871             1               ACTIVITÉ                  NAN
# 7872             1               ACTIVITÉ                  NAN
# 7873             1               ACTIVITÉ                  NAN
# 7874           NAN               ACTIVITÉ                  NAN
# 7875           NAN               ACTIVITÉ                  NAN
#
# [7876 rows x 9 columns]

# %%
#df_clean = pd.DataFrame(df_clean, columns=['periods', 'Jour','Date','Heure','Status hors poignet',"Activité","Sommeil/Éveil","Statut de l'intervalle",'Statut Sommeil/Éveil'])

# %% [markdown]
# ### Transform the data of Activité in float data

# %%
df_clean["Activité"].dtype
# Out:
# dtype('O')

# %%
df_clean['Activité'] = df_clean['Activité'].astype(float, errors = 'ignore')

# %%
df_clean["Activité"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Calculate sum and mean activity for each period

# %%
df_sums = df_clean.groupby('periods')['Activité'].agg(['sum','mean'])

# %%
df_sums
# Out:
#               sum        mean
# periods
# day_2    101721.0  113.023333
# day_3    167278.0  185.864444
# day_4    228567.0  309.711382
# day_5    206042.0  230.988789
# day_6     87384.0   97.964126
# day_7     29368.0  215.941176
# night_1   26052.0   48.333952
# night_2   20120.0   38.470363
# night_3   76891.0  142.390741
# night_4   46662.0   86.411111
# night_5   26386.0   48.862963
# night_6   28094.0   52.025926

# %% [markdown]
# ### Find the number of Nan in 'Activité'

# %%
df_clean.groupby('periods').agg({'Activité': [ lambda x: x.isnull().sum()]})
# Out:
#         Activité
#         <lambda>
# periods
# day_2          0
# day_3          0
# day_4        162
# day_5          8
# day_6          8
# day_7          0
# night_1        1
# night_2       17
# night_3        0
# night_4        0
# night_5        0
# night_6        0

# %% [markdown]
# ### Replace nan by the mean of the associate day

# %%
for p in df_clean["periods"]:
    df_clean.loc[(df_clean.periods==p) & (df_clean['Activité'].isnull()), "Activité"] = df_sums.loc[p]["mean"]

# %% [markdown]
# ### Verify all nan are remplaced

# %%
df_clean.groupby('periods').agg({'Activité': [ lambda x: x.isnull().sum()]})
# Out:
#         Activité
#         <lambda>
# periods
# day_2          0
# day_3          0
# day_4          0
# day_5          0
# day_6          0
# day_7          0
# night_1        0
# night_2        0
# night_3        0
# night_4        0
# night_5        0
# night_6        0

# %% [markdown]
# ### Calculate activity ratio

# %%
# Daytime activity ratio = (Daytime activity/24-Hour activity) × 100.

for i in range(2, 7):
    activity_ratio = df_sums.loc[f"day_{i}"]["sum"] / (df_sums.loc[f"day_{i}"]["sum"] + df_sums.loc[f"night_{i}"]["sum"])
    print(f"activity ratio for day {i}: {activity_ratio:.2f}")
# Out:
# activity ratio for day 2: 0.75
# activity ratio for day 3: 0.57
# activity ratio for day 4: 0.78
# activity ratio for day 5: 0.83
# activity ratio for day 6: 0.65
